# %% [markdown]
# * **SECTION 1 BUILDING A BASE LINE MODEL**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from keras.models import Sequential 
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %%
#Load Data from CSV file
data = pd.read_csv('/kaggle/input/concretedata/concrete_data.csv')

# %%
#Create empty list to score mean squarred error
mse_scores = []

# %%
# Assume the last column is the target variable and the rest are features
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

#Split data into train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)
    
#Build the Model
model = Sequential()
model.add(Dense(10, input_dim = X_train.shape[1], activation = 'relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer = 'adam')
    
#Train the model
model.fit(X_train, y_train, epochs=50, verbose=1, validation_data =(X_test, y_test))
    
#Predict on test set
y_pred = model.predict(X_test)
    
#Calculate the mean squared error
    
mse = mean_squared_error(y_test, y_pred)
mse_scores.append(mse)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 8s 12ms/step - loss: 15183.2451 - val_loss: 3504.1421
# Epoch 2/50
# 23/23 [==============================] - 0s 5ms/step - loss: 3177.7739 - val_loss: 2929.8564
# Epoch 3/50
# 23/23 [==============================] - 0s 5ms/step - loss: 2599.2007 - val_loss: 2383.8142
# Epoch 4/50
# 23/23 [==============================] - 0s 5ms/step - loss: 2234.1707 - val_loss: 2053.0366
# Epoch 5/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1914.8408 - val_loss: 1780.8497
# Epoch 6/50
# 23/23 [==============================] - 0s 4ms/step - loss: 1647.2146 - val_loss: 1538.6082
# Epoch 7/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1417.1165 - val_loss: 1331.8015
# Epoch 8/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1219.6033 - val_loss: 1152.8525
# Epoch 9/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1054.0930 - val_loss: 1005.5736
# Epoch 10/50
# ...

# %%
#Calculate mean and standard deviation error

mean_mse = np.mean(mse_scores)
std_mse = np.std(mse_scores)

print("Mean of Mean Squared Errors:", mean_mse)
print("Standard Deviation of Mean Squared Errors:", std_mse)
# Out:
# Mean of Mean Squared Errors: 115.51346139634542
# Standard Deviation of Mean Squared Errors: 0.0

# %% [markdown]
# * **SECTION 2 Normalization**

# %%
from sklearn.preprocessing import StandardScaler

# Create empty list to score mean squared error
mse_scores = []

# Assume the last column is the target variable and the rest are features
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Normalize the data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split data into train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Build the Model
model = Sequential()
model.add(Dense(10, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(X_train, y_train, epochs=50, verbose=1, validation_data=(X_test, y_test))

# Predict on test set
y_pred = model.predict(X_test)

# Calculate the mean squared error
mse = mean_squared_error(y_test, y_pred)
mse_scores.append(mse)

# Calculate mean and standard deviation error
mean_mse = np.mean(mse_scores)
std_mse = np.std(mse_scores)

print("Mean of Mean Squared Errors (Normalized Data):", mean_mse)
print("Standard Deviation of Mean Squared Errors (Normalized Data):", std_mse)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 1s 9ms/step - loss: 1572.9913 - val_loss: 1472.5471
# Epoch 2/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1556.9443 - val_loss: 1457.1929
# Epoch 3/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1540.8829 - val_loss: 1442.0044
# Epoch 4/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1524.9143 - val_loss: 1426.2869
# Epoch 5/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1508.4147 - val_loss: 1410.1426
# Epoch 6/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1491.3136 - val_loss: 1393.4749
# Epoch 7/50
# 23/23 [==============================] - 0s 4ms/step - loss: 1473.5836 - val_loss: 1375.9054
# Epoch 8/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1455.0651 - val_loss: 1357.6503
# Epoch 9/50
# 23/23 [==============================] - 0s 4ms/step - loss: 1435.5277 - val_loss: 1338.4844
# Epoch 10/50
# ...

# %% [markdown]
# * **SECTION 3 Training for 100 Epochs**

# %%
from sklearn.preprocessing import StandardScaler

# Create empty list to score mean squared error
mse_scores = []

# Assume the last column is the target variable and the rest are features
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Normalize the data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split data into train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Build the Model
model = Sequential()
model.add(Dense(10, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(X_train, y_train, epochs=100, verbose=1, validation_data=(X_test, y_test))

# Predict on test set
y_pred = model.predict(X_test)

# Calculate the mean squared error
mse = mean_squared_error(y_test, y_pred)
mse_scores.append(mse)

# Calculate mean and standard deviation error
mean_mse = np.mean(mse_scores)
std_mse = np.std(mse_scores)

print("Mean of Mean Squared Errors (Normalized Data):", mean_mse)
print("Standard Deviation of Mean Squared Errors (Normalized Data):", std_mse)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 1s 9ms/step - loss: 1597.2460 - val_loss: 1500.9215
# Epoch 2/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1582.6796 - val_loss: 1486.5068
# Epoch 3/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1568.4785 - val_loss: 1471.5908
# Epoch 4/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1553.7925 - val_loss: 1456.7502
# Epoch 5/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1538.7471 - val_loss: 1441.3154
# Epoch 6/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1522.9688 - val_loss: 1425.4646
# Epoch 7/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1506.4467 - val_loss: 1408.6194
# Epoch 8/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1489.2673 - val_loss: 1390.1519
# Epoch 9/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1470.6812 - val_loss: 1371.7886
# Epoch 10/100
# ...

# %% [markdown]
# * **SECTION  4 (Adding 3 Hidden Layers in part B )**

# %%
from sklearn.preprocessing import StandardScaler

# Create empty list to score mean squared error
mse_scores = []

# Assume the last column is the target variable and the rest are features
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Normalize the data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split data into train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Build the Model
model = Sequential()
model.add(Dense(10, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(X_train, y_train, epochs=50, verbose=1, validation_data=(X_test, y_test))

# Predict on test set
y_pred = model.predict(X_test)

# Calculate the mean squared error
mse = mean_squared_error(y_test, y_pred)
mse_scores.append(mse)

# Calculate mean and standard deviation error
mean_mse = np.mean(mse_scores)
std_mse = np.std(mse_scores)

print("Mean of Mean Squared Errors (Normalized Data):", mean_mse)
print("Standard Deviation of Mean Squared Errors (Normalized Data):", std_mse)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 2s 10ms/step - loss: 1607.9171 - val_loss: 1503.5963
# Epoch 2/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1587.8342 - val_loss: 1489.0198
# Epoch 3/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1572.1338 - val_loss: 1472.9467
# Epoch 4/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1551.5739 - val_loss: 1449.5527
# Epoch 5/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1520.4736 - val_loss: 1412.4323
# Epoch 6/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1471.1356 - val_loss: 1355.3494
# Epoch 7/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1392.7168 - val_loss: 1263.4142
# Epoch 8/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1269.6455 - val_loss: 1120.4932
# Epoch 9/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1085.4341 - val_loss: 919.2136
# Epoch 10/50
# ...
