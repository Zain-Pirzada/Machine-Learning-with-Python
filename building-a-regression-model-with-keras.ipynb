# %% [markdown]
# * **SECTION 1 BUILDING A BASE LINE MODEL**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from keras.models import Sequential 
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %%
#Load Data from CSV file
data = pd.read_csv('/kaggle/input/concretedata/concrete_data.csv')

# %%
#Create empty list to score mean squarred error
mse_scores = []

# %%
# Assume the last column is the target variable and the rest are features
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Repeat the process 50 times
for _ in range(50):
    # Split data into train and test set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Build the Model
    model = Sequential()
    model.add(Dense(10, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')

    # Train the model for 50 epochs
    model.fit(X_train, y_train, epochs=50, verbose=1, validation_data=(X_test, y_test))

    # Predict on test set
    y_pred = model.predict(X_test)

    # Calculate the mean squared error
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

# Calculate mean and standard deviation of mean squared errors
mean_mse = np.mean(mse_scores)
std_mse = np.std(mse_scores)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 5s 12ms/step - loss: 133947.0781 - val_loss: 95136.3672
# Epoch 2/50
# 23/23 [==============================] - 0s 5ms/step - loss: 66118.6484 - val_loss: 43300.3398
# Epoch 3/50
# 23/23 [==============================] - 0s 5ms/step - loss: 28233.3398 - val_loss: 17213.0605
# Epoch 4/50
# 23/23 [==============================] - 0s 5ms/step - loss: 10689.1143 - val_loss: 6871.7832
# Epoch 5/50
# 23/23 [==============================] - 0s 5ms/step - loss: 4502.1421 - val_loss: 3691.2271
# Epoch 6/50
# 23/23 [==============================] - 0s 5ms/step - loss: 2939.7874 - val_loss: 2925.1880
# Epoch 7/50
# 23/23 [==============================] - 0s 5ms/step - loss: 2575.7876 - val_loss: 2742.4653
# Epoch 8/50
# 23/23 [==============================] - 0s 5ms/step - loss: 2458.0940 - val_loss: 2620.3792
# Epoch 9/50
# 23/23 [==============================] - 0s 5ms/step - loss: 2353.3770 - val_loss: 2503.3164
# Epoch 10/50
# ...

# %%
print("Mean of Mean Squared Errors:", mean_mse)
print("Standard Deviation of Mean Squared Errors:", std_mse)
# Out:
# Mean of Mean Squared Errors: 402.3339756653227
# Standard Deviation of Mean Squared Errors: 634.0475874137643

# %% [markdown]
# * **SECTION 2 Normalization**

# %%
# Assume the last column is the target variable and the rest are features
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Normalize features as described
X_normalized = (X - np.mean(X, axis=0)) / np.std(X, axis=0)

# Create empty list to store mean squared errors
mse_scores = []

# Repeat the process 50 times
for _ in range(50):
    # Split data into train and test set
    X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.3, random_state=42)

    # Build the Model
    model = Sequential()
    model.add(Dense(10, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')

    # Train the model for 50 epochs
    model.fit(X_train, y_train, epochs=50, verbose=1, validation_data=(X_test, y_test))

    # Predict on test set
    y_pred = model.predict(X_test)

    # Calculate the mean squared error
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

# Calculate mean and standard deviation of mean squared errors
mean_mse = np.mean(mse_scores)
std_mse = np.std(mse_scores)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 1s 9ms/step - loss: 1588.7301 - val_loss: 1484.5659
# Epoch 2/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1573.0330 - val_loss: 1469.4630
# Epoch 3/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1556.9607 - val_loss: 1453.9785
# Epoch 4/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1539.9971 - val_loss: 1437.6387
# Epoch 5/50
# 23/23 [==============================] - 0s 4ms/step - loss: 1522.1263 - val_loss: 1420.2761
# Epoch 6/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1503.1837 - val_loss: 1401.5076
# Epoch 7/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1482.8918 - val_loss: 1381.7467
# Epoch 8/50
# 23/23 [==============================] - 0s 4ms/step - loss: 1461.4843 - val_loss: 1361.0652
# Epoch 9/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1438.6672 - val_loss: 1339.2955
# Epoch 10/50
# ...

# %%
print("Mean of Mean Squared Errors:", mean_mse)
print("Standard Deviation of Mean Squared Errors:", std_mse)
# Out:
# Mean of Mean Squared Errors: 349.80303770724555
# Standard Deviation of Mean Squared Errors: 105.46975169325965

# %%
# We can see in Part B the standard deviation has decreased from part A

# %% [markdown]
# * **SECTION 3 Training for 100 Epochs**

# %%
# Assume the last column is the target variable and the rest are features
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Normalize features as described
X_normalized = (X - np.mean(X, axis=0)) / np.std(X, axis=0)

# Create empty list to store mean squared errors
mse_scores = []

# Repeat the process 50 times
for _ in range(50):
    # Split data into train and test set
    X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.3, random_state=42)

    # Build the Model
    model = Sequential()
    model.add(Dense(10, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')

    # Train the model for 50 epochs
    model.fit(X_train, y_train, epochs=100, verbose=1, validation_data=(X_test, y_test))

    # Predict on test set
    y_pred = model.predict(X_test)

    # Calculate the mean squared error
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

# Calculate mean and standard deviation of mean squared errors
mean_mse = np.mean(mse_scores)
std_mse = np.std(mse_scores)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 1s 9ms/step - loss: 1587.4159 - val_loss: 1486.7517
# Epoch 2/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1572.3728 - val_loss: 1473.3323
# Epoch 3/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1557.6270 - val_loss: 1459.5834
# Epoch 4/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1542.4900 - val_loss: 1445.8336
# Epoch 5/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1527.2715 - val_loss: 1431.2825
# Epoch 6/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1511.0754 - val_loss: 1416.3313
# Epoch 7/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1494.2301 - val_loss: 1400.0779
# Epoch 8/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1476.1829 - val_loss: 1382.9919
# Epoch 9/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1457.0013 - val_loss: 1364.8181
# Epoch 10/100
# ...

# %%
print("Mean of Mean Squared Errors:", mean_mse)
print("Standard Deviation of Mean Squared Errors:", std_mse)
# Out:
# Mean of Mean Squared Errors: 156.70437273579205
# Standard Deviation of Mean Squared Errors: 13.5174498749005

# %% [markdown]
# #We can see a decrease in std dv in Section 3

# %% [markdown]
# * **SECTION  4 (Adding 3 Hidden Layers in part B )**

# %%
# Assume the last column is the target variable and the rest are features
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Normalize features as described
X_normalized = (X - np.mean(X, axis=0)) / np.std(X, axis=0)

# Create empty list to store mean squared errors
mse_scores = []

# Repeat the process 50 times
for _ in range(50):
    # Split data into train and test set
    X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.3, random_state=42)

    # Build the Model
    model = Sequential()
    model.add(Dense(10, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')

    # Train the model for 50 epochs
    model.fit(X_train, y_train, epochs=50, verbose=1, validation_data=(X_test, y_test))

    # Predict on test set
    y_pred = model.predict(X_test)

    # Calculate the mean squared error
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

# Calculate mean and standard deviation of mean squared errors
mean_mse = np.mean(mse_scores)
std_mse = np.std(mse_scores)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 2s 11ms/step - loss: 1622.0718 - val_loss: 1513.7858
# Epoch 2/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1596.5421 - val_loss: 1494.8280
# Epoch 3/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1577.7358 - val_loss: 1475.9908
# Epoch 4/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1551.4926 - val_loss: 1441.8798
# Epoch 5/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1499.2074 - val_loss: 1374.4655
# Epoch 6/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1415.6383 - val_loss: 1280.4875
# Epoch 7/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1302.3441 - val_loss: 1151.7037
# Epoch 8/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1151.5614 - val_loss: 979.5485
# Epoch 9/50
# 23/23 [==============================] - 0s 5ms/step - loss: 955.7532 - val_loss: 772.5570
# Epoch 10/50
# ...

# %%
print("Mean of Mean Squared Errors:", mean_mse)
print("Standard Deviation of Mean Squared Errors:", std_mse)
# Out:
# Mean of Mean Squared Errors: 123.83845905908831
# Standard Deviation of Mean Squared Errors: 14.281924791610434
